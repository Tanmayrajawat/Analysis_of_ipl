# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanmayrajawat/Analysis_of_ipl/blob/main/analysis__of_ipl_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# done by
# #Tanmay Rajawat
# #UIT RGPV BHOPAL

# %% [markdown]
# ***Import required libraries***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ***load data***

# %%
match_df = pd.read_csv("C:\Users\rajaw\Downloads\\matches.csv")
score_df = pd.read_csv("C:\Users\rajaw\Downloads\\deliveries.csv")
match_df.head()

# %% [markdown]
# ***Matches played in every 'SEASON'***

# %%
sns.countplot(x='SEASON', data=match_df)
plt.show()

# %% [markdown]
# ***Matches played in every'CITY'***

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='CITY', data=match_df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ***Matches played by every'TEAMS'***

# %%
temp_df = pd.melt(match_df, id_vars=['MATCH_ID','SEASON'], value_vars=['TEAM1', 'TEAM2'])

plt.figure(figsize=(12,6))
sns.countplot(x='value', data=temp_df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ***'WINNER' of the matches by teams ***

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='WINNER', data=match_df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ***Show the WINNERS of every 'SEASON'***

# %%
temp_df = match_df.drop_duplicates(subset=['SEASON'], keep='last')[['SEASON', 'WINNER']].reset_index(drop=True)
temp_df
# Out:
#    SEASON                 WINNER
# 0    2017         Mumbai Indians
# 1    2008       Rajasthan Royals
# 2    2009        Deccan Chargers
# 3    2010    Chennai Super Kings
# 4    2011    Chennai Super Kings
# 5    2012  Kolkata Knight Riders
# 6    2013         Mumbai Indians
# 7    2014  Kolkata Knight Riders
# 8    2015         Mumbai Indians
# 9    2016    Sunrisers Hyderabad

# %% [markdown]
# ***Toss decision percentage***

# %%
temp_series = match_df.TOSS_DECISION.value_counts()
labels = (np.array(temp_series.index))
sizes = (np.array((temp_series / temp_series.sum())*100))
colors = ['green', 'red']
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.title("Toss decision percentage")
plt.show()

# %% [markdown]
# ***'TOSS_DECISION' by every'SEASON'***

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='SEASON', hue='TOSS_DECISION', data=match_df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # Mumbai Indians vs Rajasthan Royals

# %%
MIvsRR = match_df[match_df['WINNER']=="Mumbai Indians"]

# %%
MIasteam2 = MIvsRR[MIvsRR['TEAM1']=='Rajasthan Royals']

# %%
MIwins= MIasteam2.append(MIvsRR[MIvsRR['TEAM2']=='Rajasthan Royals'])

# %% [markdown]
# ***Performance of Mumbai Indians City wise***

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='CITY',data=MIwins)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ***Mumbai Indians vs Rajasthan Royals***

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='TEAM1',data=MIwins)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # ***Thank You***
